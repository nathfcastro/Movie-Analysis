# %% [markdown]
# # Project 3 Part 1
# Student Name: Nathalie Castro

# %%
# Imports 
import pandas as pd
import numpy as np

# %%
# Remote URL to the IMDB data
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
# Loading the remote data
basics_df = pd.read_csv(basics_url, sep="\t", low_memory=False)
# Verify
basics_df
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9835146  tt9916848  tvEpisode              Episode #3.17
# 9835147  tt9916850  tvEpisode              Episode #3.19
# 9835148  tt9916852  tvEpisode              Episode #3.20
# 9835149  tt9916856      short                   The Wind
# 9835150  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 9835146              Episode #3.17       0      2010      \N             \N
# 9835147              Episode #3.19       0      2010      \N             \N
# 9835148              Episode #3.20       0      2010      \N             \N
# 9835149                   The Wind       0      2015      \N             27
# 9835150  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9835146         Action,Drama,Family
# 9835147         Action,Drama,Family
# 9835148         Action,Drama,Family
# 9835149                       Short
# 9835150  Adventure,Animation,Comedy
#
# [9835151 rows x 9 columns]

# %%
# Remote URL to the IMDB data
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
# Loading the remote data
akas_df = pd.read_csv(akas_url, sep="\t", low_memory=False)
# Verify
akas_df
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 35831900  tt9916852         5             Episódio #3.20     PT       pt
# 35831901  tt9916852         6             Episodio #3.20     IT       it
# 35831902  tt9916852         7               एपिसोड #3.20     IN       hi
# 35831903  tt9916856         1                   The Wind     DE       \N
# 35831904  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay             \N               0
# 1                  \N  literal title               0
# 2         imdbDisplay             \N               0
# 3         imdbDisplay             \N               0
# 4         imdbDisplay             \N               0
# ...               ...            ...             ...
# 35831900           \N             \N               0
# 35831901           \N             \N               0
# 35831902           \N             \N               0
# 35831903  imdbDisplay             \N               0
# 35831904     original             \N               1
#
# [35831905 rows x 8 columns]

# %%
# Remote URL to the IMDB data
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
# Loading the remote data
ratings_df = pd.read_csv(ratings_url, sep="\t", low_memory=False)
# Verify
ratings_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1968
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1814
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2611
# ...            ...            ...       ...
# 1308288  tt9916730            8.3        10
# 1308289  tt9916766            7.0        21
# 1308290  tt9916778            7.2        36
# 1308291  tt9916840            8.8         6
# 1308292  tt9916880            8.2         6
#
# [1308293 rows x 3 columns]

# %% [markdown]
# ## Processing

# %%
# Replace "\N" with np.nan
akas_df.replace({"\\N": np.nan}, inplace=True)

# %%
# Replace "\N" with np.nan
ratings_df.replace({"\\N": np.nan}, inplace=True)

# %%
# Replace "\N" with np.nan
basics_df.replace({"\\N": np.nan}, inplace=True)
basics_df["startYear"] = basics_df["startYear"].astype(float)
basics_df["endYear"] = basics_df["endYear"].astype(float)

# %%
# Eliminate movies that are null for runtimeMinutes
basics_df.dropna(axis=0, subset=["runtimeMinutes"], inplace=True)
basics_df
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9835101  tt9916754      movie  Chico Albuquerque - Revelações
# 9835107  tt9916766  tvEpisode                  Episode #10.15
# 9835142  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9835149  tt9916856      short                        The Wind
# 9835150  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult  startYear  endYear  \
# 0                            Carmencita       0     1894.0      NaN
# 1                Le clown et ses chiens       0     1892.0      NaN
# 2                        Pauvre Pierrot       0     1892.0      NaN
# 3                           Un bon bock       0     1892.0      NaN
# 4                      Blacksmith Scene       0     1893.0      NaN
# ...                                 ...     ...        ...      ...
# 9835101  Chico Albuquerque - Revelações       0     2013.0      NaN
# 9835107                  Episode #10.15       0     2019.0      NaN
# 9835142      Horrid Henry's Comic Caper       0     2014.0      NaN
# 9835149                        The Wind       0     2015.0      NaN
# 9835150       Horrid Henry Knows It All       0     2014.0      NaN
#
#         runtimeMinutes                       genres
# 0                    1            Documentary,Short
# 1                    5              Animation,Short
# 2                    4     Animation,Comedy,Romance
# 3                   12              Animation,Short
# 4                    1                 Comedy,Short
# ...                ...                          ...
# 9835101             49                  Documentary
# 9835107             43  Family,Game-Show,Reality-TV
# 9835142             11   Adventure,Animation,Comedy
# 9835149             27                        Short
# 9835150             10   Adventure,Animation,Comedy
#
# [2899737 rows x 9 columns]

# %%
# Eliminate movies that are null for genre
basics_df.dropna(axis=0, subset=["genres"], inplace=True)
basics_df
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9835101  tt9916754      movie  Chico Albuquerque - Revelações
# 9835107  tt9916766  tvEpisode                  Episode #10.15
# 9835142  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9835149  tt9916856      short                        The Wind
# 9835150  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult  startYear  endYear  \
# 0                            Carmencita       0     1894.0      NaN
# 1                Le clown et ses chiens       0     1892.0      NaN
# 2                        Pauvre Pierrot       0     1892.0      NaN
# 3                           Un bon bock       0     1892.0      NaN
# 4                      Blacksmith Scene       0     1893.0      NaN
# ...                                 ...     ...        ...      ...
# 9835101  Chico Albuquerque - Revelações       0     2013.0      NaN
# 9835107                  Episode #10.15       0     2019.0      NaN
# 9835142      Horrid Henry's Comic Caper       0     2014.0      NaN
# 9835149                        The Wind       0     2015.0      NaN
# 9835150       Horrid Henry Knows It All       0     2014.0      NaN
#
#         runtimeMinutes                       genres
# 0                    1            Documentary,Short
# 1                    5              Animation,Short
# 2                    4     Animation,Comedy,Romance
# 3                   12              Animation,Short
# 4                    1                 Comedy,Short
# ...                ...                          ...
# 9835101             49                  Documentary
# 9835107             43  Family,Game-Show,Reality-TV
# 9835142             11   Adventure,Animation,Comedy
# 9835149             27                        Short
# 9835150             10   Adventure,Animation,Comedy
#
# [2823080 rows x 9 columns]

# %%
# Keep only titleType==Movie

# Create a filter than gets titleType = Movie for all rows
is_movie = basics_df["titleType"] == "movie"

# Apply the filter
basics_df = basics_df.loc[is_movie, :]
basics_df
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9834917  tt9916362     movie
# 9835001  tt9916538     movie
# 9835042  tt9916622     movie
# 9835069  tt9916680     movie
# 9835101  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9834917                                              Coven
# 9835001                                Kuambil Lagi Hatiku
# 9835042        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9835069  De la ilusión al desconcierto: cine colombiano...
# 9835101                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 8                                               Miss Jerry       0     1894.0
# 144                          The Corbett-Fitzsimmons Fight       0     1897.0
# 570                            The Story of the Kelly Gang       0     1906.0
# 587                                      L'enfant prodigue       0     1907.0
# 672                         The Fairylogue and Radio-Plays       0     1908.0
# ...                                                    ...     ...        ...
# 9834917                                           Akelarre       0     2020.0
# 9835001                                Kuambil Lagi Hatiku       0     2019.0
# 9835042        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9835069  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9835101                     Chico Albuquerque - Revelações       0     2013.0
#
#          endYear runtimeMinutes                      genres
# 8            NaN             45                     Romance
# 144          NaN            100      Documentary,News,Sport
# 570          NaN             70  Action,Adventure,Biography
# 587          NaN             90                       Drama
# 672          NaN            120           Adventure,Fantasy
# ...          ...            ...                         ...
# 9834917      NaN             92               Drama,History
# 9835001      NaN            123                       Drama
# 9835042      NaN             57                 Documentary
# 9835069      NaN            100                 Documentary
# 9835101      NaN             49                 Documentary
#
# [382010 rows x 9 columns]

# %%
# Create a filter that selects all movies with a startYear between 2000 and 2022
between_2000_2022 = (basics_df["startYear"] >= 2000) & (basics_df["startYear"] <= 2022)

# Apply the filter
basics_df = basics_df.loc[between_2000_2022, :]
basics_df
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 76059    tt0077684     movie
# ...            ...       ...
# 9834917  tt9916362     movie
# 9835001  tt9916538     movie
# 9835042  tt9916622     movie
# 9835069  tt9916680     movie
# 9835101  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 76059                    Histórias de Combóios em Portugal
# ...                                                    ...
# 9834917                                              Coven
# 9835001                                Kuambil Lagi Hatiku
# 9835042        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9835069  De la ilusión al desconcierto: cine colombiano...
# 9835101                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0     2021.0
# 34803                                       Kate & Leopold       0     2001.0
# 61116            El tango del viudo y su espejo deformante       0     2020.0
# 67669                           The Other Side of the Wind       0     2018.0
# 76059                    Histórias de Combóios em Portugal       0     2022.0
# ...                                                    ...     ...        ...
# 9834917                                           Akelarre       0     2020.0
# 9835001                                Kuambil Lagi Hatiku       0     2019.0
# 9835042        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9835069  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9835101                     Chico Albuquerque - Revelações       0     2013.0
#
#          endYear runtimeMinutes                  genres
# 13082        NaN             94             Documentary
# 34803        NaN            118  Comedy,Fantasy,Romance
# 61116        NaN             70                   Drama
# 67669        NaN            122                   Drama
# 76059        NaN             46             Documentary
# ...          ...            ...                     ...
# 9834917      NaN             92           Drama,History
# 9835001      NaN            123                   Drama
# 9835042      NaN             57             Documentary
# 9835069      NaN            100             Documentary
# 9835101      NaN             49             Documentary
#
# [223240 rows x 9 columns]

# %%
# Eliminate movies that include "Documentary" in genre

# Create a filter that gets all non-documentary movies
is_not_documentary = ~basics_df["genres"].str.contains("documentary", case=False)

# Apply the filter
basics_df = basics_df.loc[is_not_documentary, :]
basics_df
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9834824  tt9916170     movie
# 9834833  tt9916190     movie
# 9834872  tt9916270     movie
# 9834917  tt9916362     movie
# 9835001  tt9916538     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9834824                                      The Rehearsal
# 9834833                                          Safeguard
# 9834872                           Il talento del calabrone
# 9834917                                              Coven
# 9835001                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear  \
# 34803                               Kate & Leopold       0     2001.0
# 61116    El tango del viudo y su espejo deformante       0     2020.0
# 67669                   The Other Side of the Wind       0     2018.0
# 86801                            The Naked Monster       0     2005.0
# 93938                         Crime and Punishment       0     2002.0
# ...                                            ...     ...        ...
# 9834824                                   O Ensaio       0     2019.0
# 9834833                                  Safeguard       0     2020.0
# 9834872                   Il talento del calabrone       0     2020.0
# 9834917                                   Akelarre       0     2020.0
# 9835001                        Kuambil Lagi Hatiku       0     2019.0
#
#          endYear runtimeMinutes                     genres
# 34803        NaN            118     Comedy,Fantasy,Romance
# 61116        NaN             70                      Drama
# 67669        NaN            122                      Drama
# 86801        NaN            100       Comedy,Horror,Sci-Fi
# 93938        NaN            126                      Drama
# ...          ...            ...                        ...
# 9834824      NaN             51                      Drama
# 9834833      NaN             95  Action,Adventure,Thriller
# 9834872      NaN             84                   Thriller
# 9834917      NaN             92              Drama,History
# 9835001      NaN            123                      Drama
#
# [147451 rows x 9 columns]

# %%
# Keep only US movies.
akas_df = akas_df.loc[akas_df["region"] == "US", :]
akas_df
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35831431  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35831501  tt9916620         1                          The Copeland Case
# 35831590  tt9916702         1              Loving London: The Playground
# 35831633  tt9916756         1                   Pretty Pretty Black Girl
# 35831649  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 35831431     US      NaN  imdbDisplay                    NaN               0
# 35831501     US      NaN  imdbDisplay                    NaN               0
# 35831590     US      NaN          NaN                    NaN               0
# 35831633     US      NaN  imdbDisplay                    NaN               0
# 35831649     US      NaN  imdbDisplay                    NaN               0
#
# [1435233 rows x 8 columns]

# %%
# Basics: Keep only US movies

# Get the ratings that have tconst within the basics titleId
only_US = basics_df["tconst"].isin(akas_df["titleId"])

# Apply the filter
basics_df = basics_df.loc[only_US, :]
basics_df
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9834289  tt9914942     movie
# 9834684  tt9915872     movie
# 9834824  tt9916170     movie
# 9834833  tt9916190     movie
# 9834917  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9834289                             Life Without Sara Amat
# 9834684                               The Last White Witch
# 9834824                                      The Rehearsal
# 9834833                                          Safeguard
# 9834917                                              Coven
#
#                                      originalTitle isAdult  startYear  \
# 34803                               Kate & Leopold       0     2001.0
# 61116    El tango del viudo y su espejo deformante       0     2020.0
# 67669                   The Other Side of the Wind       0     2018.0
# 86801                            The Naked Monster       0     2005.0
# 93938                         Crime and Punishment       0     2002.0
# ...                                            ...     ...        ...
# 9834289                 La vida sense la Sara Amat       0     2019.0
# 9834684                  My Girlfriend is a Wizard       0     2019.0
# 9834824                                   O Ensaio       0     2019.0
# 9834833                                  Safeguard       0     2020.0
# 9834917                                   Akelarre       0     2020.0
#
#          endYear runtimeMinutes                     genres
# 34803        NaN            118     Comedy,Fantasy,Romance
# 61116        NaN             70                      Drama
# 67669        NaN            122                      Drama
# 86801        NaN            100       Comedy,Horror,Sci-Fi
# 93938        NaN            126                      Drama
# ...          ...            ...                        ...
# 9834289      NaN             74                      Drama
# 9834684      NaN             97       Comedy,Drama,Fantasy
# 9834824      NaN             51                      Drama
# 9834833      NaN             95  Action,Adventure,Thriller
# 9834917      NaN             92              Drama,History
#
# [86654 rows x 9 columns]

# %%
# Keep only US movies

# Get the ratings that have tconst within the akas titleId
only_US = ratings_df["tconst"].isin(akas_df["titleId"])

# Apply the filter
ratings_df = ratings_df.loc[only_US, :]
ratings_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1968
# 1        tt0000002            5.8       263
# 4        tt0000005            6.2      2611
# 5        tt0000006            5.1       181
# 6        tt0000007            5.4       817
# ...            ...            ...       ...
# 1308254  tt9916200            8.1       229
# 1308255  tt9916204            8.1       262
# 1308262  tt9916348            8.3        18
# 1308263  tt9916362            6.4      5319
# 1308268  tt9916428            3.8        14
#
# [497708 rows x 3 columns]

# %%
basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86654 entries, 34803 to 9834917
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          86654 non-null  object
#  1   titleType       86654 non-null  object
#  2   primaryTitle    86654 non-null  object
#  3   originalTitle   86654 non-null  object
#  4   isAdult         86654 non-null  object
#  5   startYear       86654 non-null  float64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  86654 non-null  object
#  8   genres          86654 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 6.6+ MB

# %%
akas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1435233 entries, 5 to 35831649
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1435233 non-null  object
#  1   ordering         1435233 non-null  int64
#  2   title            1435233 non-null  object
#  3   region           1435233 non-null  object
#  4   language         3907 non-null     object
#  5   types            978610 non-null   object
#  6   attributes       46532 non-null    object
#  7   isOriginalTitle  1433888 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 98.5+ MB

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497708 entries, 0 to 1308268
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         497708 non-null  object
#  1   averageRating  497708 non-null  float64
#  2   numVotes       497708 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.2+ MB

# %%
# Save each DataFrame to compressed files
ratings_df.to_csv("Data/title_ratings.csv.gz", compression='gzip',index=False)
akas_df.to_csv("Data/title_akas.csv.gz", compression='gzip',index=False)
basics_df.to_csv("Data/title_basics.csv.gz", compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings_df = pd.read_csv("Data/title_ratings.csv.gz", low_memory=False)
ratings_df
# Out:
#            tconst  averageRating  numVotes
# 0       tt0000001            5.7      1968
# 1       tt0000002            5.8       263
# 2       tt0000005            6.2      2611
# 3       tt0000006            5.1       181
# 4       tt0000007            5.4       817
# ...           ...            ...       ...
# 497703  tt9916200            8.1       229
# 497704  tt9916204            8.1       262
# 497705  tt9916348            8.3        18
# 497706  tt9916362            6.4      5319
# 497707  tt9916428            3.8        14
#
# [497708 rows x 3 columns]

# %%
# Open saved file and preview again
akas_df = pd.read_csv("Data/title_akas.csv.gz", low_memory=False)
akas_df
# Out:
#            titleId  ordering                                      title  \
# 0        tt0000001         6                                 Carmencita
# 1        tt0000002         7                     The Clown and His Dogs
# 2        tt0000005        10                           Blacksmith Scene
# 3        tt0000005         1                        Blacksmithing Scene
# 4        tt0000005         6                        Blacksmith Scene #1
# ...            ...       ...                                        ...
# 1435228  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 1435229  tt9916620         1                          The Copeland Case
# 1435230  tt9916702         1              Loving London: The Playground
# 1435231  tt9916756         1                   Pretty Pretty Black Girl
# 1435232  tt9916764         1                                         38
#
#         region language        types             attributes  isOriginalTitle
# 0           US      NaN  imdbDisplay                    NaN              0.0
# 1           US      NaN          NaN  literal English title              0.0
# 2           US      NaN  imdbDisplay                    NaN              0.0
# 3           US      NaN  alternative                    NaN              0.0
# 4           US      NaN  alternative                    NaN              0.0
# ...        ...      ...          ...                    ...              ...
# 1435228     US      NaN  imdbDisplay                    NaN              0.0
# 1435229     US      NaN  imdbDisplay                    NaN              0.0
# 1435230     US      NaN          NaN                    NaN              0.0
# 1435231     US      NaN  imdbDisplay                    NaN              0.0
# 1435232     US      NaN  imdbDisplay                    NaN              0.0
#
# [1435233 rows x 8 columns]

# %%
# Open saved file and preview again
basics_df = pd.read_csv("Data/title_basics.csv.gz", low_memory=False)
basics_df
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 86649  tt9914942     movie                             Life Without Sara Amat
# 86650  tt9915872     movie                               The Last White Witch
# 86651  tt9916170     movie                                      The Rehearsal
# 86652  tt9916190     movie                                          Safeguard
# 86653  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# 3                              The Naked Monster        0     2005.0      NaN
# 4                           Crime and Punishment        0     2002.0      NaN
# ...                                          ...      ...        ...      ...
# 86649                 La vida sense la Sara Amat        0     2019.0      NaN
# 86650                  My Girlfriend is a Wizard        0     2019.0      NaN
# 86651                                   O Ensaio        0     2019.0      NaN
# 86652                                  Safeguard        0     2020.0      NaN
# 86653                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 86649              74                      Drama
# 86650              97       Comedy,Drama,Fantasy
# 86651              51                      Drama
# 86652              95  Action,Adventure,Thriller
# 86653              92              Drama,History
#
# [86654 rows x 9 columns]
